# %% [markdown]
# <a href="https://colab.research.google.com/github/hhaemin/computer_vision/blob/main/PIL.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from PIL import Image
import matplotlib.pyplot as plt

# %%
## image read
img = Image.open('image.jpeg')


## image visualize
plt.imshow(img)
plt.show()
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1440x1440 at 0x7F38C350FAD0>

# %% [markdown]
# ## Image resize

# %%
w,h = img.size
img_resize = img.resize((w//2, h//2))
plt.imshow(img_resize)
plt.show()

img_resize = img.resize((w*2, h*2))
plt.imshow(img_resize)
plt.show()

## resize options -> 
# https://pillow.readthedocs.io/en/stable/handbook/concepts.html?highlight=resize#PIL.Image.NEAREST

# %% [markdown]
# ## Image crop

# %%
def two_image_show(im1, im2):
    plt.subplot(1,2,1)
    plt.imshow(im1)
    plt.subplot(1,2,2)    
    plt.imshow(im2)
    plt.show()
    
img_crop = img.crop((w//4, h//4, w*3//4, h*3//4))

plt.imshow(img_crop)
## (left, upper, right, lower)

two_image_show(img, img_crop)

# %% [markdown]
# ## Image rotate

# %%
img_rotate = img.rotate(45)   ## degree, NOT radian

# img_rotate.show() 
plt.imshow(img_rotate)

# %%
img_flip = img.transpose(Image.FLIP_LEFT_RIGHT)   ## FLIP_TOP_BOTTOM

two_image_show(img, img_flip)

# %%
img_flip_and_rotate = img.rotate(45).transpose(Image.FLIP_LEFT_RIGHT)

img_flip_and_rotate.save('save_img.png')

# %% [markdown]
# # 결론
#
# 이미지 처리 그 자체만으로는 PIL 라이브러리가 훨씬 간단하고 편리하다.
#
# 하지만, 복잡한 컴퓨터비전 알고리즘의 적용이나, 딥러닝/머신러닝 모델을 개발할 때에는 PIL 의 함수만으로는 수행할 수 없다.
